# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/Production_LivestockPrimary_E_All_Data/Production_LivestockPrimary_E_All_Data.csv', sep = ',', encoding = 'latin-1')

# %%
#data[(data['Area'] == 'Finland')]

data[data['Element'] == 'Producing Animals/Slaughtered']
# Out:
#        Area Code                                     Area  Item Code  \
# 4              2                              Afghanistan        919
# 23             2                              Afghanistan       1127
# 26             2                              Afghanistan        867
# 29             2                              Afghanistan       1058
# 33             2                              Afghanistan       1017
# ...          ...                                      ...        ...
# 22286       5817  Net Food Importing Developing Countries        995
# 22289       5817  Net Food Importing Developing Countries        999
# 22296       5817  Net Food Importing Developing Countries       1806
# 22305       5817  Net Food Importing Developing Countries       1808
# 22312       5817  Net Food Importing Developing Countries       1807
#
#                           Item  Element Code                        Element  \
# ...

# %% [markdown]
# ## Explanations of data files
# The livestock data file contains 7 columns of information, and the rest of the columns are for the yearly values.
#
# | Column name         | Explanation|
# |------------------------|--------|
# | Area Code              |     |
# | Area                   |Name of country/area|
# | Item Code              |     |
# | Item                   |Type of product     |
# | Element Code           |     |
# | Element                |If "Head": Figures relate to the total domestic production whether inside or outside the agricultural sector, i.e. it includes non-commercial production and production from kitchen gardens. Unless otherwise indicated, production is reported at the farm level for crop and livestock products (i.e. in the case of crops, excluding harvesting losses) and in terms of live weight for fish items (i.e. the actual ex-water weight at the time of the catch). All data shown relate to total meat production from both commercial and farm slaughter. Data are expressed in terms of dressed carcass weight, excluding offal and slaughter fats. Production of beef and buffalo meat includes veal; mutton and goat meat includes meat from lambs and kids; pig meat includes bacon and ham in fresh equivalent. Poultry meat includes meat from all domestic birds and refers, wherever possible, to ready-to-cook weight.  |
# | Unit                   |     |
#
#
# For each year there is also a column with the year + F, which signifies the meaning of the data.
#
# | Meaning of flag         | Flag      |
# |------------------------|--------|
# | Unofficial data        | *      |
# | FAO Estimate           | F      |
# | Official data          | NaN    |
# | Calculated data | Fc |
# | Aggregate, may include official, semi-official, estimated or calculated data | A |
# | Data not available | M |
