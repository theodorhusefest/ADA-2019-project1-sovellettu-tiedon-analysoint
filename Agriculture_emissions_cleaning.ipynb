# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
emission_data = pd.read_csv('raw_data/Emissions_Agriculture_Agriculture_total_E_All_Data_(Norm).csv', sep = ',', encoding = 'latin-1')
emission_data
# Out:
#         Country Code      Country  Item Code                  Item  \
# 0                  2  Afghanistan       5058  Enteric Fermentation
# 1                  2  Afghanistan       5058  Enteric Fermentation
# 2                  2  Afghanistan       5058  Enteric Fermentation
# 3                  2  Afghanistan       5058  Enteric Fermentation
# 4                  2  Afghanistan       5058  Enteric Fermentation
# ...              ...          ...        ...                   ...
# 326177          5873         OECD       1709    Agricultural Soils
# 326178          5873         OECD       1709    Agricultural Soils
# 326179          5873         OECD       1709    Agricultural Soils
# 326180          5873         OECD       1709    Agricultural Soils
# 326181          5873         OECD       1709    Agricultural Soils
#
#         Element Code                     Element  Year Code  Year       Unit  \
# 0               7231           Emissions (CO2eq)       1961  1961  Gigagrams
# 1               7231           Emissions (CO2eq)       1962  1962  Gigagrams
# 2               7231           Emissions (CO2eq)       1963  1963  Gigagrams
# 3               7231           Emissions (CO2eq)       1964  1964  Gigagrams
# 4               7231           Emissions (CO2eq)       1965  1965  Gigagrams
# ...              ...                         ...        ...   ...        ...
# 326177          7243  Emissions (CO2eq) from N2O       2012  2012  Gigagrams
# 326178          7243  Emissions (CO2eq) from N2O       2013  2013  Gigagrams
# 326179          7243  Emissions (CO2eq) from N2O       2014  2014  Gigagrams
# 326180          7243  Emissions (CO2eq) from N2O       2030  2030  Gigagrams
# 326181          7243  Emissions (CO2eq) from N2O       2050  2050  Gigagrams
#
#               Value Flag
# 0         5054.3459    A
# 1         5151.5228    A
# 2         5372.3989    A
# 3         5440.3650    A
# 4         5577.5580    A
# ...             ...  ...
# 326177  507201.5669    A
# 326178  515750.7919    A
# 326179  526015.4357    A
# 326180  525722.7988    A
# 326181  542459.3841    A
#
# [326182 rows x 11 columns]

# %% [markdown]
# ## Explanation of agriculture emissions datafile
#
# The emissions data in our dataset covers all emissions from agriculture. That is, both the emissions from crops and livestock production. There are different categories where the emissions come from but we are only interested in the total in this project. We will therefor clean out so that we only have the total emissions for agriculture. We are also only interested in CO2 emissions for this project and will therefore clean out the other types of emissions as well. Since we are studying emission on a continents level we will also only keep the data for the different continents.
#
# ## Data cleaning

# %%
emission_data.Item.unique()
# Out:
# array(['Enteric Fermentation', 'Manure Management', 'Rice Cultivation',
#        'Synthetic Fertilizers', 'Manure applied to Soils',
#        'Manure left on Pasture', 'Crop Residues',
#        'Cultivation of Organic Soils', 'Burning - Crop residues',
#        'Burning - Savanna', 'Agriculture total', 'Agricultural Soils'],
#       dtype=object)

# %%
emissions = emission_data[emission_data.Item.str.contains('Agriculture total')] # Keep only agriculture total emissions

# %%
# Keep only continent data
continents = ['Africa', 'Northern America', 'South America', 'Asia', 'Oceania', 'Europe']
emission_continent = emissions[emissions.Country.isin(continents)].rename({'Country': 'Area'}, axis=1)

emission_continent
# Out:
#         Country Code     Area  Item Code               Item  Element Code  \
# 277052          5100   Africa       1711  Agriculture total          7231
# 277053          5100   Africa       1711  Agriculture total          7231
# 277054          5100   Africa       1711  Agriculture total          7231
# 277055          5100   Africa       1711  Agriculture total          7231
# 277056          5100   Africa       1711  Agriculture total          7231
# ...              ...      ...        ...                ...           ...
# 307686          5500  Oceania       1711  Agriculture total          7243
# 307687          5500  Oceania       1711  Agriculture total          7243
# 307688          5500  Oceania       1711  Agriculture total          7243
# 307689          5500  Oceania       1711  Agriculture total          7243
# 307690          5500  Oceania       1711  Agriculture total          7243
#
#                            Element  Year Code  Year       Unit        Value  \
# 277052           Emissions (CO2eq)       1961  1961  Gigagrams  233438.4994
# 277053           Emissions (CO2eq)       1962  1962  Gigagrams  237662.8732
# 277054           Emissions (CO2eq)       1963  1963  Gigagrams  241883.7192
# 277055           Emissions (CO2eq)       1964  1964  Gigagrams  248689.6524
# 277056           Emissions (CO2eq)       1965  1965  Gigagrams  255912.4287
# ...                            ...        ...   ...        ...          ...
# 307686  Emissions (CO2eq) from N2O       2012  2012  Gigagrams  116863.3514
# 307687  Emissions (CO2eq) from N2O       2013  2013  Gigagrams   78615.5455
# 307688  Emissions (CO2eq) from N2O       2014  2014  Gigagrams   89613.8889
# 307689  Emissions (CO2eq) from N2O       2030  2030  Gigagrams  100990.5540
# 307690  Emissions (CO2eq) from N2O       2050  2050  Gigagrams  103421.7009
#
#        Flag
# 277052    A
# 277053    A
# 277054    A
# 277055    A
# 277056    A
# ...     ...
# 307686    A
# 307687    A
# 307688    A
# 307689    A
# 307690    A
#
# [1008 rows x 11 columns]

# %%
# Is any information missing?
print("Missing information in categorized dataset: \n", emission_continent.isna().sum())
# Out:
# Missing information in categorized dataset:
#  Country Code    0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Year Code       0
# Year            0
# Unit            0
# Value           0
# Flag            0
# dtype: int64

# %%
# Save to pickle
emission_continent.to_pickle('./data/pickles/agriculture_emissions_continents.pkl')

# %% [markdown]
# We also have another emissions file with some categories to easier be able to determine differences in emission between crops and livestock production. This dataset already has countries filtered out and only contains the different continents.

# %%
categorized_data = pd.read_csv('raw_data/Emission_data.csv', sep = ',', encoding = 'latin-1')
categorized_data
# Out:
#      Domain Code                 Domain  Area Code     Area  Element Code  \
# 0             EI  Emissions intensities       5100   Africa          7231
# 1             EI  Emissions intensities       5100   Africa          7231
# 2             EI  Emissions intensities       5100   Africa          7231
# 3             EI  Emissions intensities       5100   Africa          7231
# 4             EI  Emissions intensities       5100   Africa          7231
# ...          ...                    ...        ...      ...           ...
# 8155          EI  Emissions intensities       5500  Oceania          5510
# 8156          EI  Emissions intensities       5500  Oceania          5510
# 8157          EI  Emissions intensities       5500  Oceania          5510
# 8158          EI  Emissions intensities       5500  Oceania          5510
# 8159          EI  Emissions intensities       5500  Oceania          5510
#
#                 Element  Item Code                    Item  Year Code  Year  \
# 0     Emissions (CO2eq)       1718  Cereals excluding rice       1961  1961
# 1     Emissions (CO2eq)       1718  Cereals excluding rice       1962  1962
# 2     Emissions (CO2eq)       1718  Cereals excluding rice       1963  1963
# 3     Emissions (CO2eq)       1718  Cereals excluding rice       1964  1964
# 4     Emissions (CO2eq)       1718  Cereals excluding rice       1965  1965
# ...                 ...        ...                     ...        ...   ...
# 8155         Production       1035               Meat, pig       2012  2012
# 8156         Production       1035               Meat, pig       2013  2013
# 8157         Production       1035               Meat, pig       2014  2014
# 8158         Production       1035               Meat, pig       2015  2015
# 8159         Production       1035               Meat, pig       2016  2016
#
#            Unit        Value Flag  \
# 0     gigagrams    6404.6437    A
# 1     gigagrams    6841.1636    A
# 2     gigagrams    7246.6931    A
# 3     gigagrams    7400.0959    A
# 4     gigagrams    7668.5256    A
# ...         ...          ...  ...
# 8155     tonnes  500824.0000    A
# 8156     tonnes  503040.0000    A
# 8157     tonnes  506860.0000    A
# 8158     tonnes  514315.0000    A
# 8159     tonnes  521955.0000    A
#
#                                        Flag Description
# 0     Aggregate, may include official, semi-official...
# 1     Aggregate, may include official, semi-official...
# 2     Aggregate, may include official, semi-official...
# 3     Aggregate, may include official, semi-official...
# 4     Aggregate, may include official, semi-official...
# ...                                                 ...
# 8155  Aggregate, may include official, semi-official...
# 8156  Aggregate, may include official, semi-official...
# 8157  Aggregate, may include official, semi-official...
# 8158  Aggregate, may include official, semi-official...
# 8159  Aggregate, may include official, semi-official...
#
# [8160 rows x 14 columns]

# %%
categorized_data['Item'].unique()
# Out:
# array(['Cereals excluding rice', 'Rice, paddy', 'Meat, cattle',
#        'Milk, whole fresh cow', 'Meat, goat', 'Milk, whole fresh goat',
#        'Meat, buffalo', 'Milk, whole fresh buffalo', 'Meat, sheep',
#        'Milk, whole fresh sheep', 'Milk, whole fresh camel',
#        'Meat, chicken', 'Eggs, hen, in shell', 'Meat, pig'], dtype=object)

# %%
sheep_prod = categorized_data[categorized_data.Item.str.contains('sheep')]

sheep_data = sheep_prod.groupby(['Area','Element','Year','Unit']).agg({'Value':'sum'})
sheep_data['Item'] = 'Sheep'

# %%
sheep_data.reset_index()
# Out:
#               Area            Element  Year       Unit        Value   Item
# 0           Africa  Emissions (CO2eq)  1961  gigagrams   26107.8934  Sheep
# 1           Africa  Emissions (CO2eq)  1962  gigagrams   25742.8884  Sheep
# 2           Africa  Emissions (CO2eq)  1963  gigagrams   25928.7068  Sheep
# 3           Africa  Emissions (CO2eq)  1964  gigagrams   26531.4870  Sheep
# 4           Africa  Emissions (CO2eq)  1965  gigagrams   27693.8435  Sheep
# ..             ...                ...   ...        ...          ...    ...
# 667  South America         Production  2012     tonnes  290741.0000  Sheep
# 668  South America         Production  2013     tonnes  283684.0000  Sheep
# 669  South America         Production  2014     tonnes  276685.0000  Sheep
# 670  South America         Production  2015     tonnes  264212.0000  Sheep
# 671  South America         Production  2016     tonnes  257805.0000  Sheep
#
# [672 rows x 6 columns]
